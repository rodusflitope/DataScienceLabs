# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### 👨‍🏫👩‍🏫 Cuerpo Docente:
#
# - Profesores: Diego Cortez, Gabriel Iturra
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Nicolás Cabello, Cristopher Urbina
#
# ### 👨‍💻👩‍💻 Estudiantes:
# - Estudiante n°1: Daniel Vargas
# - Estudiante n°2: Rafael Tapia
#
# _Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir._
#
# ---

# %% [markdown]
# ---
#
# ## 📖 Enunciado

# %% [markdown]
# <div align="center">
#     <img src='https://github.com/MDS7202/MDS7202/blob/main/recursos/2025-01/proyecto/proyecto.png?raw=true' style="border-radius: 12px">
# </div>

# %% [markdown]
# En el competitivo universo de las bebidas gaseosas, la empresa **SodAI Drinks 🥤** ha logrado destacarse por su creatividad, diversidad de productos y enfoque centrado en el cliente. Ofrece una extensa gama de bebidas carbonatadas que abarca distintos segmentos del mercado: desde productos premium en presentaciones sofisticadas, hasta gaseosas accesibles para el consumo masivo, disponibles en diversos tamaños y tipos de envases.
#
# La compañía opera en múltiples regiones y zonas, sirviendo a una variedad de puntos de venta que incluyen desde tiendas de conveniencia y minimarkets hasta el canal frío tradicional. Cada tipo de cliente tiene sus particularidades: algunos reciben entregas hasta 4 veces por semana, mientras que otros son visitados por la fuerza de ventas solo una vez semanalmente. Esta diversidad de perfiles representa tanto una oportunidad como un desafío comercial: ¿cómo saber qué productos tienen más chances de ser comprados por cada cliente en un momento dado?
#
# Con el objetivo de aumentar la facturación de forma inteligente y mejorar la eficiencia de su estrategia de ventas, **SodAI Drinks** decide crear una nueva célula interna de innovación: el equipo **Deep Drinkers 🤖**, cuyo propósito es aplicar ciencia de datos para anticiparse a las necesidades del cliente y potenciar el negocio desde una perspectiva basada en información.
#
# El corazón de esta iniciativa es el desarrollo de un sistema predictivo personalizado para cada cliente. Para ello, **Deep Drinkers** convoca a un equipo de Data Scientists y especialistas en *machine learning* con una misión clara: construir un modelo predictivo que, cada semana, pueda estimar la probabilidad de compra de cada producto del portafolio para cada cliente activo.
#
# El modelo deberá tener en cuenta múltiples factores, incluyendo:
# - **Tipo de cliente**, ej. "TIENDA DE CONVENIENCIA", "MINIMARKET".
# - **Frecuencia de entregas y visitas**, indicadores del nivel de actividad comercial.
# - **Ubicación geográfica** (por región y zona).
# - **Preferencias históricas de consumo**, inferidas por patrones de compra anteriores.
# - **Características del producto**, como marca, categoría, segmento, tipo de envase y tamaño
#
# El objetivo final es que, **cada semana**, se genere una tabla de productos priorizados: para cada cliente, un listado de productos ordenado por su probabilidad estimada de compra. Esta información será enviada al equipo comercial, que podrá usarla en call center, para incrementar las chances de concretar ventas al ofrecer justo lo que el cliente probablemente quiere comprar.
#
# Este proyecto representa un cambio de paradigma en la forma en que **SodAI Drinks** gestiona su fuerza de ventas: de un enfoque reactivo y generalista, a uno proactivo, basado en datos y profundamente personalizado. Así, la empresa no solo espera aumentar su rentabilidad, sino también construir relaciones más sólidas con sus clientes, ofreciéndoles recomendaciones más relevantes y oportunas.
#
# Para lograr lo anterior, el equipo **Deep Drinkers** contará con los siguientes conjuntos de datos, junto a sus respectivos atributos:
#
# - **Datos transaccionales** (`transacciones.parquet`): contiene el historial de compras realizadas por los clientes.
# 	- `customer_id`: identificador único del cliente que realizó la compra.
# 	- `product_id`: identificador único del producto comprado.
# 	- `purchase_date`: fecha en que se realizó la transacción.
# 	- `order_id`: identificar de la orden de su pedido.
# 	- `payment`	monto total pagado por la transacción.
#
# - **Datos de clientes** (`clientes.parquet`): incluye las características de cada cliente.
# 	- `customer_id`: identificador único del cliente.
# 	- `region_id`: identificador de la región geográfica donde se encuentra el cliente.
# 	- `customer_type`: tipo de cliente según el canal comercial, por ejemplo, “TIENDA DE CONVENIENCIA”.
# 	- `Y`: coordenada geográfica de latitud.
# 	- `X`: coordenada geográfica de longitud.
# 	- `num_deliver_per_week`: cantidad de entregas semanales que recibe el cliente.
# 	- `num_visit_per_week`: frecuencia de visitas de la fuerza de ventas por semana.
#
# - **Datos de productos** (`productos.parquet`): describe las características de los productos del portafolio.
# 	- `product_id`: identificador único del producto.
# 	- `brand`: marca comercial del producto.
# 	- `category`: categoría general del producto, como “BEBIDAS CARBONATADAS”.
# 	- `sub_category`: subcategoría dentro de la categoría principal, por ejemplo, “GASEOSAS”.
# 	- `segment`: segmento de mercado al que pertenece el producto, como “PREMIUM”.
# 	- `package`: tipo de envase del producto.
# 	- `size`: tamaño del producto en litros.

# %% [markdown]
# ## 📚 Reglas

# %% [markdown]
# <center>
# <img src="https://media1.tenor.com/m/0Qtv_cQ4ITsAAAAd/necohaus-grey-name.gif" width="450">

# %% [markdown]
# El proyecto consta de **dos entregas parciales** y una **entrega final** en donde la primera entrega la idea es poder reflejar lo aprendido durante la primera mitad del curso, que será sobre los contenidos relacionados a *machine learning*, la segunda será sobre los contenidos de la segunda mitad del curso relacionados a *MLOps* y por último la entrega final constará de dos partes, donde la primera será relacionada con experimentación sobre nuevos datasets que serán disponibilizados durante las últimas semanas del curso de manera incremental y una segunda parte que será el informe final escrito que deberá explicar el desarrollo del proyecto completo, como tambien los resultados y análisis de los experimentos realizados sobre los datasets incrementales. La idea es que todo el código esté desarrollado durante las primeras dos entregas y luego en la entrega final sólo se ejecute el código sobre nuevos conjuntos de datos.
#
# La idea de generar el proyecto por etapas es poder aliviar la carga de trabajo en las últimas semanas del semestre donde sabemos que están muy cargado con entregas, pruebas y exámenes de otros ramos, y así garantizamos que habiendo la desarrollado las dos primeras entregas parciales, tendrán el grueso del proyecto listo para luego experimentar y documentar.
#
# ---
# ### **Fechas de entrega**
# - **Entrega parcial 1**: 12 de Septiembre
# - **Entrega parcial 2**: Por definir
# - **Entrega final**: Por definir
#
# ---
#
# ### **Requisitos del proyecto**
# - **Grupos**: Formar equipos de **2 personas**. No se aceptarán trabajos individuales o grupos con más integrantes.
# - **Consultas**: Cualquier duda fuera del horario de clases debe ser planteada en el foro correspondiente. Los mensajes enviados al equipo docente serán respondidos únicamente por este medio. Por favor, revisen las respuestas anteriores en el foro antes de realizar nuevas consultas.
# - **Plagio**: La copia o reutilización no autorizada de trabajos de otros grupos está **estrictamente prohibida**. El incumplimiento de esta norma implicará la anulación inmediata del proyecto y una posible sanción académica.
# - **Material permitido**: Pueden usar cualquier material del curso, ya sea notas, lecturas, códigos, o referencias proporcionadas por los docentes, que consideren útil para el desarrollo del proyecto.
#
# ---
#
# ### **Entregables y etapas**
#
# #### **1. Entrega Parcial 1**
# - Dispondrán de los archivos de datos **productos.parquet**, **clientes.parquet** y **transacciones.parquet** para el modelamiento inicial.
# - Utilizarán estos archivos para desarrollar lo solicitado para la entrega 1.
# - En esta etapa, se espera que apliquen todos los conocimientos aprendidos durante la primera parte del curso relacionados con *machine learning*.
# - **Informe**: No se exige un avance del informe en esta etapa, sólo un notebook con su desarrollo actual, pero se **recomienda comenzar** a redactar el informe final en paralelo para disminuir la carga académica en las etapas posteriores.
#
# #### **2. Entrega Parcial 2**
# - En esta entrega, deberán aplicar los conocimientos aprendidos durante la segunda mitad del curso sobre *MLOps*
# - Se espera que implementen estos conocimientos para desplegar su modelo elegido en la primera entrega y crear *pipelines* automatizados que simulen un entorno productivo.
# - **Informe**: similar a la primera etapa, no se exige un avance del informe, pero se **recomienda avanzar con su redacción** para evitar una acumulación de trabajo en la etapa final.
#
# #### **3. Entrega Final**
# - En la entrega final, deberán realizar dos etapas:
# 	- La primera etapa es sobre experimentación utilizando datasets incrementales que se irán disponibilizando de manera parcial, para que vayan generando predicciones con su modelo ya desplegado. El objetivo de esta etapa es poder testear su solución *end-to-end* y que vayan analizando los resultados obtenidos a medida que se van agregando más datos.
# 	- La segunda etapa consiste en redactar un informe final que deberá explicar el desarrollo completo de tu proyecto y un análisis profundo de sus resultados de experimentación. Este informe debera incluir a lo menos las siguientes secciones:
# 		- Análisis exploratorio de datos
# 		- Metodología aplicada
# 		- Selección y entrenamiento de modelos
# 		- Evaluación de resultados
# 		- Optimización de modelos
# 		- Interpretabilidad
# 		- Re-entrenamiento
# 		- Tracking con MLFlow
# 		- Creación de la aplicación web con Gradio y FastAPI
#
# Es **altamente recomendable** ir redactando el informe en paralelo al desarrollo de los modelos para garantizar que toda la información relevante quede documentada adecuadamente.
#
# ### Nota Final
#
# La calificación final de su proyecto se calculará utilizando la siguiente ponderación:
#
# $$Nota Final = 0.30 * EntregaParcial1 + 0.40 * EntregaParcial2 + 0.30 * EntregaFinal$$
#
# ---
#
# ### **Instrucciones importantes**
#
# 1. **Formato del informe**:
#    - El informe debe estar integrado dentro de un **Jupyter Notebook**. No es necesario subirlo a una plataforma externa, pero debe cumplir con los siguientes requisitos:
#      - Estructura clara y ordenada.
#      - Código acompañado de explicaciones detalladas.
#      - Resultados presentados de forma visual y analítica.
#
# 2. **Descuento por informes deficientes**:
#    - Cualquier sección del informe que no tenga una explicación adecuada o no respete el formato será penalizada con un descuento en la nota. Esto incluye código sin comentarios o análisis que no sean coherentes con los resultados presentados.
#    - Comentarios sin formatear de ChatGPT o herramientas similares serán penalizados (e.g: "Inserta tu modelo acá", etc.)

# %% [markdown]
# # 📬 Entrega Parcial 1 (30% del Proyecto)

# %% [markdown]
# ### 📪 Fecha de Entrega: 12 de Septiembre

# %% [markdown]
# ## 📌 Abstract [0.25 puntos]
#
# <center>
# <img src="https://i.redd.it/h5ptnsyabqvd1.gif" width="400" height="300">

# %% [markdown]
# En esta sección, deben redactar un Abstract claro y conciso para su proyecto. El Abstract debe responder a las siguientes preguntas clave:
#
# - **Descripción del problema**: ¿Cuál es el objetivo del proyecto? ¿Qué se intenta predecir o analizar?
# - **Datos de entrada**: ¿Qué datos tienen disponibles? ¿Cuáles son sus principales características?
# - **Métrica de evaluación**: ¿Cómo medirán el desempeño de sus modelos? Expliquen por qué eligieron esta métrica basándose en el análisis exploratorio de los datos.
# - **Modelos y transformaciones**: ¿Qué modelos utilizarán y por qué? ¿Qué transformaciones o preprocesamientos aplicaron a los datos?
# - **Resultados generales**: ¿El modelo final cumplió con los objetivos del proyecto? ¿Cuáles fueron las conclusiones más importantes?
#
# **Importante**: Escriban esto despues de haber resuelto el resto de la tarea.

# %% [markdown]
# Este proyecto aborda el desafío de predecir la probabilidad de compra semanal de productos para cada cliente de la empresa SodAI Drinks, con el objetivo de optimizar las estrategias de venta. Utilizando datos transaccionales, de clientes y de productos, se construyó un modelo de clasificación binaria. El problema se estructuró transformando el historial de compras en un conjunto de datos semanal, donde cada registro representa una combinación única de cliente, producto y semana. Para manejar el desbalance inherente entre compras y no-compras, se aplicó una técnica de muestreo de negativos. La métrica de evaluación principal fue el PR AUC (Average Precision Score), elegida por su robustez en escenarios con clases desbalanceadas, complementada por el F1-Score para la clase positiva. Se evaluaron múltiples modelos, incluyendo `RandomForestClassifier` y `GradientBoostingClassifier`, de los cuales `LGBMClassifier` demostró el mejor rendimiento inicial. Tras una optimización de hiperparámetros con Optuna, el modelo final `LGBMClassifier` logró un desempeño superior, validando su capacidad para generar recomendaciones de productos priorizadas y cumpliendo el objetivo de crear una herramienta de apoyo proactivo para el equipo comercial.

# %% [markdown]
# ## 📌 Pre-procesamiento [0.5 puntos]
#
# <center>
# <img src="https://media0.giphy.com/media/10zsjaH4g0GgmY/giphy.gif?cid=6c09b9523xtlunksc9amikw09zk1bmiqwjqnt70ae82rk877&ep=v1_gifs_search&rid=giphy.gif&ct=g" width="400" height="300">

# %% [markdown]
# Tal como en muchos otros problemas de negocio, los datos probablemente deben ser pre procesados antes de aplicar cualquier técnica de analítica. Bajo esa premisa, en esta sección deben desarrollar código que les permita **preparar los datos** de tal forma que les permita resolver el problema planteado. Para esto, pueden aplicar procesamientos como:
#
# - Transformaciones de tipo de dato (str, int, etc)
# - Cruce de información
# - Eliminación de duplicados
# - Filtros de fila y/o columnas
#
# *Hint: ¿Qué forma debería tener la data para resolver un problema de aprendizaje supervisado?*
#
# Todo proceso llevado a cabo debe estar bien documentado y justificado en el informe, explicando el por qué se decidió realizar en funcion de los datos presentados y los objetivos planteados del proyecto.

# %%
# !pip install pandas pyarrow numpy scikit-learn lightgbm optuna shap matplotlib seaborn

# %%
# Definimos semilla global para reproducibilidad
RANDOM_STATE = 10

# %%
import pandas as pd
clientes = pd.read_parquet('clientes.parquet')
productos = pd.read_parquet('productos.parquet')
transacciones = pd.read_parquet('transacciones.parquet')

print("Dimensiones de los df:")
print(f"Clientes: {clientes.shape}")
print(f"Productos: {productos.shape}")
print(f"Transacciones: {transacciones.shape}")
print("\n")

print("Información de las columnas:")
print("CLIENTES:")
print(clientes.info())
print("\nPRODUCTOS:")
print(productos.info())
print("\nTRANSACCIONES:")
print(transacciones.info())
print("\n")

print("Primeras filas de los df:")
print("CLIENTES:")
print(clientes.head())
print("\nPRODUCTOS:")
print(productos.head())
print("\nTRANSACCIONES:")
print(transacciones.head())
# Out:
# Dimensiones de los df:
# Clientes: (1569, 8)
# Productos: (971, 7)
# Transacciones: (254936, 5)
#
#
# Información de las columnas:
# CLIENTES:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1569 entries, 10705 to 12273
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           1569 non-null   int64
#  1   region_id             1569 non-null   int64
#  2   zone_id               1569 non-null   int64
#  3   customer_type         1569 non-null   object
#  4   Y                     1569 non-null   float64
#  5   X                     1568 non-null   float64
#  6   num_deliver_per_week  1569 non-null   int64
#  7   num_visit_per_week    1569 non-null   int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 110.3+ KB
# None
#
# PRODUCTOS:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 7 columns):
# ...

# %% [markdown]
# Filtramos columnas para quedar con las que aportan información importante sin agregar mucho ruido. Por esto descartamos las columnas de latitud pues tenemos el region_id que podemos tratar como categorías que ya dividen en segmentos comerciables y que son más interpretables

# %%
clientes = clientes.drop(columns=['X', 'Y'])

# %% [markdown]
# Limpiemos los datos manejando duplicados. Para esto primero veamos cuantos duplicados hay

# %%
print("Duplicados en los df:")
print(f"Clientes: {clientes.duplicated().sum()}")
print(f"Productos: {productos.duplicated().sum()}")
print(f"Transacciones: {transacciones.duplicated().sum()}")
# Out:
# Duplicados en los df:
# Clientes: 0
# Productos: 0
# Transacciones: 885

# %% [markdown]
# Eliminamos duplicados

# %%
clientes = clientes.drop_duplicates()
productos = productos.drop_duplicates()
transacciones = transacciones.drop_duplicates()

print("Duplicados eliminados. Nuevas dimensiones:")
print(f"Clientes: {clientes.shape}")
print(f"Productos: {productos.shape}")
print(f"Transacciones: {transacciones.shape}")
# Out:
# Duplicados eliminados. Nuevas dimensiones:
# Clientes: (1569, 6)
# Productos: (971, 7)
# Transacciones: (254051, 5)

# %% [markdown]
# Finalmente podemos notar que la columna items esta como float lo que no tiene sentido pues representa cantidad de bultos comprados por cliente en aquella transacción la cual debe ser entera por lo tanto la revisamos para ver que puede ser.

# %%
print(transacciones['items'].head(10))
print("Datos:")
print(f"   - Valor promedio de items: {transacciones['items'].mean():.2f}")
print(f"   - Rango de cantidad de bultos comprados: {transacciones['items'].min()} a {transacciones['items'].max()}")
print(f"   - Valores negativos en items: {(transacciones['items'] < 0).sum()}")
print(f"   - Valores no enteros en items: {(transacciones['items'] % 1 != 0).sum()}")
# Out:
# 124   -0.333333
# 127    3.666667
# 344    2.333333
# 349   -2.333333
# 354    1.000000
# 359   -2.333333
# 362   -2.333333
# 363   -1.000000
# 365   -0.333333
# 367   -1.000000
# Name: items, dtype: float64
# Datos:
#    - Valor promedio de items: 4.38
#    - Rango de cantidad de bultos comprados: -399.6666666666667 a 1000.3333333333334
#    - Valores negativos en items: 8346
#    - Valores no enteros en items: 146451

# %% [markdown]
# Revisando valores podemos notar que esta columna no tiene mucho sentido pues posee muchos valores negativos, muchos valores no enteros y un rango extremadamente amplio que no se espera de bultos comprados. Debido a la dificultad para interpretar y usar esta columna pues no sabemos si aporta información o si es un error, la eliminamos.

# %%
transacciones = transacciones.drop(columns=['items'])

# %% [markdown]
# ## 📌 EDA [0.5 puntos]
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExbHZ6aGdkd21tYTI3cW8zYWhyYW5wdGlyb2s3MmRzeTV0dzQ1NWlueiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3k1hJubTtOAKPKx4k3/giphy.gif" width="400" height="200">

# %% [markdown]
# En esta sección, se debe realizar un análisis exploratorio de los datos para comprender su estructura, detectar posibles problemas y obtener información relevante para el entrenamiento de los modelos. La idea es que puedan detectar **patrones en los datos** que les permitan resolver el problema con mayor facilidad.
#
# Se deben responder preguntas a partir de lo que puedan visualizar/obtener, por ejemplo:
#
# - Clientes y productos
#
#     - ¿Cuántos clientes únicos hay en el dataset?
#
#     - ¿Cuántos productos únicos se encuentran en los datos?
#
# - Periodo y frecuencia
#
#     - ¿De qué periodo es la información disponible?
#
#     - ¿Cuál es la frecuencia de los registros (diaria, semanal, mensual, etc.)?
#
# - Calidad de los datos
#
#     - ¿Existen valores nulos en el dataset? ¿Cuántos? ¿Cómo se pueden tratar?
#
#     - ¿Hay datos raros, como cantidades negativas o inconsistencias? Genere tests de validación para identificar estos problemas.
#
# - Patrones de compra
#
#     - ¿Cuántos productos compra en promedio cada cliente semana a semana?
#
#     - ¿Cuántas transacciones ha realizado cada cliente?
#
#     - ¿Cuál es el periodo de recompra promedio de cada SKU?

# %%
# Clientes unicos
print(f"Número de clientes únicos en el dataset final: {clientes['customer_id'].nunique()}")

# Productos unicos
print(f"Número de productos únicos en el dataset final: {productos['product_id'].nunique()}")
# Out:
# Número de clientes únicos en el dataset final: 1569
# Número de productos únicos en el dataset final: 971

# %%
import matplotlib.pyplot as plt

# Periodo de tiempo
transacciones['purchase_date'] = pd.to_datetime(transacciones['purchase_date'])
start_date = transacciones['purchase_date'].min()
end_date = transacciones['purchase_date'].max()

print(f"Periodo de tiempo en transacciones: {start_date} a {end_date} (todo el año 2024)")

# Frecuencia registros
fechas = pd.Series(pd.to_datetime(transacciones['purchase_date']))

# Frecuencia diaria
print("Frecuencia diaria de transacciones:")
conteo_dia = fechas.value_counts().sort_index()
print(conteo_dia.head())

print("\nFrecuencia diaria promedio:")
print(conteo_dia.mean())

# Frecuencia semanal
conteo_semana = fechas.dt.to_period("W").value_counts().sort_index()
conteo_semana.plot(kind="bar", figsize=(10,4))
plt.title("Frecuencia por semana")
plt.show()

# Frecuencia mensual
conteo_mes = fechas.dt.to_period("M").value_counts().sort_index()
conteo_mes.plot(kind="bar", figsize=(10,4))
plt.title("Frecuencia por mes")
plt.show()
# Out:
# Periodo de tiempo en transacciones: 2024-01-01 00:00:00 a 2024-12-31 00:00:00 (todo el año 2024)
# Frecuencia diaria de transacciones:
# purchase_date
# 2024-01-01     166
# 2024-01-02    1125
# 2024-01-03     772
# 2024-01-04    1064
# 2024-01-05     922
# Name: count, dtype: int64
#
# Frecuencia diaria promedio:
# 694.1284153005464

# %% [markdown]
# Podemos observar que la frecuencia promedio diaria es de aproximadamente 665 y que, en general, agregado por semana es estable pues se mueve dentro mismo orden de magnitud (no hay semana con 10 veces más compras que otra).

# %%
#Existencia de nulos (ya sabemos de preprocesamiento que no hay nulos)
print("Valores nulos por columna:")
print("CLIENTES:")
print(clientes.isnull().sum())
print("\nPRODUCTOS:")
print(productos.isnull().sum())
print("\nTRANSACCIONES:")
print(transacciones.isnull().sum())
print("\n")
# Out:
# Valores nulos por columna:
# CLIENTES:
# customer_id             0
# region_id               0
# zone_id                 0
# customer_type           0
# num_deliver_per_week    0
# num_visit_per_week      0
# dtype: int64
#
# PRODUCTOS:
# product_id      0
# brand           0
# category        0
# sub_category    0
# segment         0
# package         0
# size            0
# dtype: int64
#
# TRANSACCIONES:
# customer_id      0
# product_id       0
# order_id         0
# purchase_date    0
# dtype: int64

# %% [markdown]
# No existen valores nulos dentro de las columnas que seleccionamos

# %%
# Verificamos valores negativos en columnas numéricas
print("Verificando valores negativos:")
print(f"   - Entregas por semana negativas: {(clientes['num_deliver_per_week'] < 0).sum()}")
print(f"   - Visitas por semana negativas: {(clientes['num_visit_per_week'] < 0).sum()}")
print(f"   - Tamaños de producto negativos o cero: {(productos['size'] <= 0).sum()}")

# Verificar rangos de datos
print("\n Verificando rangos de datos:")
print(f"   - Rango de entregas por semana: {clientes['num_deliver_per_week'].min()} a {clientes['num_deliver_per_week'].max()}")
print(f"   - Rango de tamaños: {productos['size'].min()} a {productos['size'].max()}")
# Out:
# Verificando valores negativos:
#    - Entregas por semana negativas: 0
#    - Visitas por semana negativas: 0
#    - Tamaños de producto negativos o cero: 0
#
#  Verificando rangos de datos:
#    - Rango de entregas por semana: 1 a 6
#    - Rango de tamaños: 0.125 a 20.0

# %% [markdown]
# Revisemos entonces los patrones de compra

# %%
# Primero creo la columna week para poder analizar por semanas
transacciones['purchase_date'] = pd.to_datetime(transacciones['purchase_date'])
fecha_inicio = transacciones['purchase_date'].min()

def get_week_number(date, start_date):
    days_diff = (date - start_date).days
    return days_diff // 7

transacciones['week'] = transacciones['purchase_date'].apply(lambda d: get_week_number(d, fecha_inicio))

# Productos por cliente por semana
productos_por_cliente_semana = (transacciones
                               .groupby(['customer_id', 'week'])
                               .size()
                               .reset_index(name='num_productos'))

promedio_productos_semana = productos_por_cliente_semana['num_productos'].mean()
print(f"Promedio de productos comprados por cliente por semana: {promedio_productos_semana:.2f}")

# Transacciones por cliente (total, no por semana)
transacciones_por_cliente = (transacciones
                           .groupby('customer_id')
                           .size()
                           .reset_index(name='num_transacciones'))

print(f"Promedio de transacciones por cliente: {transacciones_por_cliente['num_transacciones'].mean():.2f}")

# Período de recompra por SKU
transacciones_ordenadas = transacciones.sort_values(['customer_id', 'product_id', 'purchase_date'])

# Calculamos la diferencia de días entre compras consecutivas del mismo producto por el mismo cliente
transacciones_ordenadas['dias_desde_ultima_compra'] = (
    transacciones_ordenadas
    .groupby(['customer_id', 'product_id'])['purchase_date']
    .diff()
    .dt.days
)

# Filtramos valores nulos (primera compra de cada cliente-producto)
periodos_recompra = transacciones_ordenadas['dias_desde_ultima_compra'].dropna()

print(f"Período de recompra promedio por SKU: {periodos_recompra.mean():.2f} días")
# Out:
# Promedio de productos comprados por cliente por semana: 5.47
# Promedio de transacciones por cliente: 170.50
# Período de recompra promedio por SKU: 16.53 días

# %% [markdown]
# ## 📌 Holdout [0.25 puntos]
#
# Para evaluar correctamente el modelo y garantizar su capacidad de generalización, se deben dividir los datos en tres conjuntos:
# - `Entrenamiento` : Para ajustar los parámetros.
# - `Validación`: Para optimizar hiperparámetros y seleccionar el mejor modelo.
# - `Prueba` : Para evaluar el rendimiento final en datos no vistos.
#
# 👀 **Hint**: *Recuerde que los datos tienen una temporalidad que debe considerarse al momento de separarlos, para evitar fugas de información. Es importante justificar la estrategia de partición elegida y visualizar la distribución temporal de los conjuntos generados*

# %% [markdown]
# Para evitar data leakage es importante ordenar por tiempo y usar los datos en distintos conjuntos separados cronologicamente para que no se capture data del futuro al entrenar o validar (entrenamiento, validación y test en ese orden)

# %%
# Ordenar por tiempo para evitar data leakage
transacciones_sorted = transacciones.sort_values('purchase_date')
total = len(transacciones_sorted)

# Índices de corte
idx_train = int(total * 0.70)
idx_val = int(total * 0.85)

# División de los datos
train_trans = transacciones_sorted.iloc[:idx_train]
val_trans = transacciones_sorted.iloc[idx_train:idx_val]
test_trans = transacciones_sorted.iloc[idx_val:]

print(f"\nTamaños:")
print(f"Train: {len(train_trans):,} ({len(train_trans)/total*100:.1f}%)")
print(f"Val: {len(val_trans):,} ({len(val_trans)/total*100:.1f}%)")
print(f"Test: {len(test_trans):,} ({len(test_trans)/total*100:.1f}%)")

print(f"\nFechas de corte:")
print(f"Train: hasta {train_trans['purchase_date'].max()}")
print(f"Val: hasta {val_trans['purchase_date'].max()}")
print(f"Test: hasta {test_trans['purchase_date'].max()}")
# Out:
# Tamaños:
# Train: 177,835 (70.0%)
# Val: 38,108 (15.0%)
# Test: 38,108 (15.0%)
#
# Fechas de corte:
# Train: hasta 2024-10-05 00:00:00
# Val: hasta 2024-11-23 00:00:00
# Test: hasta 2024-12-31 00:00:00

# %% [markdown]
# ## 📌 Feature Engineering [0.5 puntos]
#
# <center>
# <img src="https://i.imgur.com/CmXZSSC.gif" width="300" height="200">

# %% [markdown]
# En esta sección, se deben construir pipelines para automatizar el preprocesamiento de los datos, lo cual garantizará que el flujo de trabajo sea reproducible y eficiente para esta entrega y las futuras. El objetivo es aplicar una serie de transformaciones en un orden definido para asegurar que los datos estén listos para los modelos a entrenar. El pipeline final debe incluir las técnicas de pre-procesamiento que se deben aplicar a los distintos datos (según lo que consideren necesario para el problema). Por ejemplo:
#
# - **Imputación de valores nulos**: Manejo de datos faltantes mediante estrategias adecuadas (media, mediana, moda, interpolación, etc.).
#
# - **Transformaciones personalizadas**: Uso de ColumnTransformer para aplicar diferentes transformaciones a columnas específicas.
#
# - **Codificación de variables categóricas**: Convertir datos categóricos a un formato numérico adecuado (One-Hot Encoding, Label Encoding, etc.).
#
# - **Discretización de variables**: Conversión de variables numéricas continuas en categorías si son relevantes para el desempeño del modelo a entrenar.
#
# - **Estandarización o normalización** : Ajustar la escala de los datos para mejorar el rendimiento de los algoritmos sensibles a la magnitud de las variables.
#
# - **Eliminación o transformación de valores atípicos**: Identificar y tratar con datos outliers para mejorar la robustez del modelo.
#
# - **Nuevas características** : Creación de variables adicionales que puedan aportar información relevante al modelo.
#
# Cada una de estas transformaciones debe ser justificada en función de su relevancia para el problema y los datos, y es importante evaluar su impacto en el rendimiento del modelo. Además, el pipeline debe ser flexible y modular para poder probar diferentes configuraciones de preprocesamiento.

# %% [markdown]
# Queremos predecir si el consumidor X comprara el producto Y en la semana Z por lo que es conveniente agrupar los datos de esta forma, es decir, cada registro representa una semana con su data y el label es si el cliente compra el producto Y en esta semana siendo 1 si lo compra y 0 si no lo compra. Es importante notar que al pasar los registros a semanas la data del cliente y los productos no cambia, solo las transacciones se deben manejar para crear features que capturen la información que aportan como por ejemplo agregar la cantidad que se compro cierto objeto en la semana. Para esto revisamos el rango de fechas con el objetivo de saber como dividir

# %%
fecha_inicio = transacciones['purchase_date'].min()
fecha_fin = transacciones['purchase_date'].max()

print(f"Rango de fechas en transacciones: {fecha_inicio} a {fecha_fin}")
# Out:
# Rango de fechas en transacciones: 2024-01-01 00:00:00 a 2024-12-31 00:00:00

# %% [markdown]
# Separamos el dataset por semana, ya que, el problema pide predecir las compras por semana por esto nos combiene tener el dataset de tal forma que producto-cliente-semana define un registro y que el label sea si en ese registro se compra o no el producto por ese usuario esa semana. Podemos notar que hay demasiadas combinaciones producto, semana, consumidor por lo que hacemos negative sampling para que sea manejable (hacemos sampleo de casos donde no se compró el objeto por ese consumidor en esa semana en vez de tomar todas las opciones posibles). Es importante notar que no tomamos el order_id en este paso pues representa muchas categorías que pueden ser muy dificiles de manejar para el modelo.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

RATIO_NEG_POS = 2  # Ratio de casos negativos a positivos para hacer el negative sampling

class WeeklyDatasetBuilder(BaseEstimator, TransformerMixin):
    def __init__(self, ratio_neg_pos: int = 1, random_state: int | None = RANDOM_STATE):
        self.ratio_neg_pos = ratio_neg_pos
        self.random_state = random_state

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        transacciones = X['transacciones'].copy()
        clientes = X['clientes']
        productos = X['productos']

        transacciones['purchase_date'] = pd.to_datetime(transacciones['purchase_date'])
        fecha_inicio = transacciones['purchase_date'].min()
        transacciones['week'] = ((transacciones['purchase_date'] - fecha_inicio).dt.days // 7).astype(int)

        # Casos positivos que salen de las transacciones reales (por eso para todos el label es 1)
        positivos = (
            transacciones.groupby(['customer_id', 'product_id', 'week'])
            .size()
            .reset_index(name='count')
        )
        positivos['purchased'] = 1

        # Universo cliente-producto-semana
        semanas_totales = range(transacciones['week'].min(), transacciones['week'].max() + 1)
        clientes_activos = transacciones['customer_id'].unique()
        productos_vendidos = transacciones['product_id'].unique()
        universe = pd.MultiIndex.from_product(
            [clientes_activos, productos_vendidos, semanas_totales],
            names=['customer_id', 'product_id', 'week']
        ).to_frame(index=False)

        dataset_completo = universe.merge(positivos, on=['customer_id', 'product_id', 'week'], how='left')
        dataset_completo['purchased'] = dataset_completo['purchased'].fillna(0)

        # Negative sampling estratificado por cliente (para que sea realista sino podria sobrerepresentar clientes inactivos)
        casos_positivos = dataset_completo[dataset_completo['purchased'] == 1]
        casos_negativos = dataset_completo[dataset_completo['purchased'] == 0]

        negativos_sample = []
        for cliente in clientes_activos:
            neg_cliente = casos_negativos[casos_negativos['customer_id'] == cliente]
            pos_cliente = casos_positivos[casos_positivos['customer_id'] == cliente]
            # Calculo cuantos negativos tomar (si tengo muchos positivos y no quedan negativos, tomo todos los negativos)
            n_sample = min(len(pos_cliente) * self.ratio_neg_pos, len(neg_cliente))
            if n_sample > 0:
                neg_sample = neg_cliente.sample(n=int(n_sample), random_state=self.random_state)
                negativos_sample.append(neg_sample)

        # Caso borde porque en la práctica siempre hay negativos
        if len(negativos_sample) > 0:
            casos_negativos_sample = pd.concat(negativos_sample, ignore_index=True)
            dataset_completo = pd.concat([casos_positivos, casos_negativos_sample], ignore_index=True)
        else:
            dataset_completo = casos_positivos.copy()

        # Añado atributos de clientes y productos
        dataset_final = (
            dataset_completo
            .merge(clientes, on='customer_id', how='left')
            .merge(productos, on='product_id', how='left')
        )

        # Elimininar columna 'count' si existe porque no es necesaria, solo quiero saber si compró o no el producto
        if 'count' in dataset_final.columns:
            dataset_final = dataset_final.drop(columns=['count'])

        return dataset_final

# Re-construir dataset_final con el builder 
builder = WeeklyDatasetBuilder(ratio_neg_pos=RATIO_NEG_POS, random_state=RANDOM_STATE)
dataset_final_train = builder.fit_transform({
    'transacciones': train_trans,
    'clientes': clientes,
    'productos': productos,
})

dataset_final_val = builder.transform({
    'transacciones': val_trans,
    'clientes': clientes,
    'productos': productos,
})

dataset_final_test = builder.transform({
    'transacciones': test_trans,
    'clientes': clientes,
    'productos': productos,
})

print("Dataset final de entrenamiento info:")
print(dataset_final_train.info())
print("\nPrimeras filas:")
print(dataset_final_train.head())
print(f"\nDimensiones del dataset final de entrenamiento: {dataset_final_train.shape}")
# Out:
# Dataset final de entrenamiento info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438468 entries, 0 to 438467
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   customer_id           438468 non-null  int64
#  1   product_id            438468 non-null  int64
#  2   week                  438468 non-null  int64
#  3   purchased             438468 non-null  float64
#  4   region_id             438468 non-null  int64
#  5   zone_id               438468 non-null  int64
#  6   customer_type         438468 non-null  object
#  7   num_deliver_per_week  438468 non-null  int64
#  8   num_visit_per_week    438468 non-null  int64
#  9   brand                 438468 non-null  object
#  10  category              438468 non-null  object
#  11  sub_category          438468 non-null  object
#  12  segment               438468 non-null  object
#  13  package               438468 non-null  object
# ...

# %% [markdown]
# Convertimos cada columna a algo procesable para el modelo. Notar que se deja fuera de esto a las columnas que definen cada registro como son week, product_id y client_id pues no agregan información. Para el caso de week lo usamos para agregar una feature de week cíclica, esto por 2 motivos, el primero es que week es sólo un identificador de cada registro pero no captura estacionalidad en el año lo que si aporta información, por esto se toma la semana respecto al año (como estos datos son de un año no afecta directamente pero la idea es que la pipeline generalice). El segundo punto a notar es que se uso seno y coseno, esto porque si se definieran de forma simple las semanas desde 1 a 52 para representar la semana del año, el modelo entendería que 1 y 52 estan muy lejos pero estan tan lejos como 1 de 2 por lo que se usa una función cíclica para capturar esta cercanía cíclica.

# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.pipeline import Pipeline

cat_cols = [
    'region_id',
    'customer_type',
    'brand',
    'category',
    'sub_category',
    'segment',
    'package',
]
num_base_cols = [
    'size',
    'num_deliver_per_week',
    'num_visit_per_week',
]

# Función que agrega codificación cíclica de semana y remueve 'week' asi capturo estacionalidad pues cada registro ya separa por semana
def add_week_cyclical(X: pd.DataFrame) -> pd.DataFrame:
    Xc = X.copy()
    w = (Xc['week'] % 52).astype(float)
    Xc['week_sin'] = np.sin(2 * np.pi * w / 52.0)
    Xc['week_cos'] = np.cos(2 * np.pi * w / 52.0)
    return Xc.drop(columns=['week'])

# Añadimos features
add_time = FunctionTransformer(add_week_cyclical)
num_cols = num_base_cols + ['week_sin', 'week_cos']

# Procesamos columnas categóricas y numéricas
preprocess = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(), cat_cols),
        ('num', StandardScaler(), num_cols),
    ],
    remainder='drop',
    verbose_feature_names_out=False,
)

# Pipeline completo
prep_pipeline = Pipeline(steps=[
    ('add_time', add_time),
    ('preprocess', preprocess),
])

feature_cols = cat_cols + num_base_cols + ['week']

X_train = dataset_final_train[feature_cols]; y_train = dataset_final_train['purchased']
X_val   = dataset_final_val[feature_cols];   y_val   = dataset_final_val['purchased']
X_test  = dataset_final_test[feature_cols];  y_test  = dataset_final_test['purchased']

Xt_train = prep_pipeline.fit_transform(X_train)
Xt_val   = prep_pipeline.transform(X_val)
Xt_test  = prep_pipeline.transform(X_test)

print({'train_shape': Xt_train.shape, 'val_shape': Xt_val.shape, 'test_shape': Xt_test.shape})
# Out:
# {'train_shape': (438468, 44), 'val_shape': (95007, 44), 'test_shape': (90129, 44)}

# %% [markdown]
# ## 📌 Baseline [0.25 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExN3lzeGFqZmU3NzJrZHllNjRmaHVzczJpZ29rdHdlMzVpZnQwNXo1diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/qAtZM2gvjWhPjmclZE/giphy.gif" width="300" height="200">

# %% [markdown]
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **Modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.

# %% [markdown]
# Seleccionamos un `DecisionTreeClassifier` como modelo baseline. Esta elección se debe a que es un modelo simple, rápido de entrenar e interpretable, lo que lo convierte en un excelente punto de partida para problemas de clasificación. Al establecer `class_weight='balanced'`, ayudamos al modelo a manejar el desbalance de clases presente en los datos, esto para que no se vea sobreestimada la ventaja de los modelos que si manejan balance de clases con respecto a este baseline.
#
# Aunque mostramos muchas métricas, la métrica principal que usaremos es la PR AUC (Average Precision Score), elegida por su robustez en escenarios con clases desbalanceadas, complementada por el F1-Score para la clase positiva. Ambas métricas se enfocan en la clase positiva y es por esto que fue interesante usarlas pues ambas se enfocan en la clase positiva, sobre todo la PR AUC pues además calcula sobre todos los umbrales siendo más consistente que el f1 score y por eso se eleigió como métrica primaria

# %%
from sklearn.metrics import classification_report, roc_auc_score, average_precision_score
import time

# Fruncion que automatiza el evauar modelos
def eval_model(name, pipe, X_tr, y_tr, X_va, y_va):
    start_time = time.time()
    pipe.fit(X_tr, y_tr)
    training_time = time.time() - start_time
    
    y_pred = pipe.predict(X_va)
    report = classification_report(y_va, y_pred, digits=4, output_dict=True)
    roc_auc = None
    pr_auc = None
    if hasattr(pipe, "predict_proba"):
        y_score = pipe.predict_proba(X_va)[:, 1]
        roc_auc = roc_auc_score(y_va, y_score)
        pr_auc = average_precision_score(y_va, y_score)
    print(f"\n{name} (Validación):")
    print(classification_report(y_va, y_pred, digits=4))
    if roc_auc is not None:
        print(f"ROC AUC: {roc_auc:.3f} | PR AUC: {pr_auc:.3f}")
    print(f"Tiempo de entrenamiento: {training_time:.2f} segundos")
    return {
        'model': name,
        'f1_pos': report.get('1', report.get('1.0', {}))['f1-score'],
        'recall_pos': report.get('1', report.get('1.0', {}))['recall'],
        'precision_pos': report.get('1', report.get('1.0', {}))['precision'],
        'accuracy': report['accuracy'],
        'roc_auc': roc_auc,
        'pr_auc': pr_auc,
        'training_time_s': training_time,
    }

# %%
from sklearn.base import clone
from sklearn.tree import DecisionTreeClassifier
tree_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('clf', DecisionTreeClassifier(random_state=RANDOM_STATE, class_weight='balanced')),
])
tree_results = eval_model("DecisionTreeClassifier", tree_pipe, X_train, y_train, X_val, y_val)
# Out:
# DecisionTreeClassifier (Validación):
#               precision    recall  f1-score   support
#
#          0.0     0.8772    0.6830    0.7680     63338
#          1.0     0.5605    0.8088    0.6622     31669
#
#     accuracy                         0.7249     95007
#    macro avg     0.7189    0.7459    0.7151     95007
# weighted avg     0.7716    0.7249    0.7327     95007
#
# ROC AUC: 0.805 | PR AUC: 0.637
# Tiempo de entrenamiento: 19.18 segundos

# %% [markdown]
# ## 📌 Elección de modelo [0.75 puntos]
#
# En esta sección deben escoger un modelo que se adapte a las necesidades del negocio. Para esto, pruebe al menos 3 modelos y desarrolle los siguientes aspectos para cada uno:
#
# - **Estructura y diferencias entre los modelos**: Explicar brevemente cada uno y sus hipérparámetros de mayor importancia.
# - **Clasificadores recomendados**:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro (según lo que se estime adecuado)
#
# - **Evaluación de resultados**: Se utilizará el **`classification_report`** para evaluar el rendimiento de cada modelo, destacando métricas clave como precisión, recall y F1-score. **Importante: No optimicen hiperparámetros, la idea es hacer una selección rápida del modelo.**
#
# **Nota:** Pueden ocupar mas de 1 **instancia** de modelo para resolver el problema (e.g: (modelo_1, grupo_1), (modelo_2, grupo_2), ...).
#
# A continuación, se deben responder las siguientes preguntas para evaluar el rendimiento de los modelos entrenados:
#
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de `tiempo de entrenamiento`, ¿Qué modelo considera más adecuado para experimentar con grillas de optimización?

# %% [markdown]
# Se eligieron los modelos `GradientBoostingClassifier`, `RandomForestClassifier`, `ExtraTreesClassifier` y `LGBMClassifier` por ser algoritmos basados en árboles de decisión, los cuales son robustos y suelen ofrecer un alto rendimiento en problemas de clasificación con datos tabulares como el nuestro.
#
# La selección específica permite comparar diferentes estrategias:
# - **`RandomForestClassifier`**: Un modelo de que entrena múltiples árboles en paralelo sobre subconjuntos de datos, promediando sus resultados para reducir la varianza y el sobreajuste. Es un estándar de la industria por su buen equilibrio entre rendimiento y estabilidad.
# - **`ExtraTreesClassifier`**: Similar a Random Forest, pero introduce más aleatoriedad al seleccionar los umbrales de división de los nodos, lo que puede reducir aún más la varianza y acelerar el entrenamiento.
# - **`GradientBoostingClassifier`**: Un modelo que construye árboles de forma secuencial, donde cada nuevo árbol corrige los errores del anterior. Generalmente logra una mayor precisión que los modelos de bagging (que son los que agrupan árboles y sacan métricas en conjunto), aunque puede ser más sensible al sobreajuste.
# - **`LGBMClassifier`**: Una implementación moderna y altamente optimizada de gradient boosting. Es conocido por su velocidad y eficiencia en el uso de memoria, lo que lo hace ideal para datasets grandes y para una experimentación más rápida, como la optimización de hiperparámetros. Ideal para probar una opción más moderna y rápida y como se comporta respecto a las otras.

# %%
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier

from sklearn.base import TransformerMixin
class ToDense(TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X.toarray() if hasattr(X, 'toarray') else X

results = []
model_pipes = {}

# 1) Gradient Boosting (requiere densificar)
gb_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('to_dense', ToDense()),
    ('clf', GradientBoostingClassifier(random_state=RANDOM_STATE)),
])
model_pipes["GradientBoostingClassifier"] = gb_pipe
results.append(eval_model("GradientBoostingClassifier", gb_pipe, X_train, y_train, X_val, y_val))

# 2) Random Forest
rf_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('clf', RandomForestClassifier(random_state=RANDOM_STATE)),
])
model_pipes["RandomForestClassifier"] = rf_pipe
results.append(eval_model("RandomForestClassifier", rf_pipe, X_train, y_train, X_val, y_val))

# 3) Extra Trees
et_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('clf', ExtraTreesClassifier(random_state=RANDOM_STATE)),
])
model_pipes["ExtraTreesClassifier"] = et_pipe
results.append(eval_model("ExtraTreesClassifier", et_pipe, X_train, y_train, X_val, y_val))

# Balance de clases para LightGBM
pos = int(y_train.sum())
neg = len(y_train) - pos
scale_pos_weight = neg / max(1, pos)

# 4) LightGBM
lgb_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('clf', LGBMClassifier(
        random_state=RANDOM_STATE,
        scale_pos_weight=scale_pos_weight,
    )),
])
model_pipes["LGBMClassifier"] = lgb_pipe
results.append(eval_model("LGBMClassifier", lgb_pipe, X_train, y_train, X_val, y_val))

# Resumen y selección del mejor modelo
df_res = pd.DataFrame(results)
df_res = df_res.sort_values(by=['pr_auc', 'f1_pos'], ascending=False)
print("\nResumen modelos (validación):")
print(df_res)
# Out:
# GradientBoostingClassifier (Validación):
#               precision    recall  f1-score   support
#
#          0.0     0.8091    0.8300    0.8194     63338
#          1.0     0.6415    0.6083    0.6244     31669
#
#     accuracy                         0.7561     95007
#    macro avg     0.7253    0.7191    0.7219     95007
# weighted avg     0.7532    0.7561    0.7544     95007
#
# ROC AUC: 0.830 | PR AUC: 0.675
# Tiempo de entrenamiento: 131.03 segundos
#
# RandomForestClassifier (Validación):
#               precision    recall  f1-score   support
#
#          0.0     0.8254    0.8021    0.8136     63338
#          1.0     0.6254    0.6606    0.6425     31669
#
#     accuracy                         0.7550     95007
#    macro avg     0.7254    0.7314    0.7281     95007
# weighted avg     0.7587    0.7550    0.7566     95007
#
# ROC AUC: 0.810 | PR AUC: 0.657
# Tiempo de entrenamiento: 1101.79 segundos
#
# ExtraTreesClassifier (Validación):
# ...

# %% [markdown]
# Podemos ver que todos los modelos obtuvieron mejores métricas que el modelo baseline y que el mejor este estos, en todas las métricas, es el modelo `LGBMClassifier` teniendo mejor f1_score y PR_AUC que todos los otros modelos además de ser rápido para entrenarse, por esto es el modelo que seleccionamos para seguir pues es el mejor en resultados y es un muy buen candidato a optimización de hiperparámetros por grilla.

# %% [markdown]
# ## 📌 Optimización de Hiperparámetros [1.0 puntos]
#
# <center>
# <img src="https://media1.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXJkNzdhYjlneHplaGpsbnVkdzh5dnY3Y2VyaTIzamszdGR1czJ2diZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/2rqEdFfkMzXmo/giphy.gif" width="300" height="200">

# %% [markdown]
# A partir de su análisis anterior, se debe proceder a optimizar el rendimiento del modelo seleccionado mediante la optimización de sus hiperparámetros. Para ello, se espera que implementen `Optuna` para optimizar no solo los hiperparámetros del modelo, sino también los de los preprocesadores utilizados (por ejemplo, OneHot Encoding, Scalers, etc.).
#
# En nuestro caso, tras la comparación de modelos, simplificamos la búsqueda para optimizar únicamente **LightGBM** con `Optuna`, usando PR AUC en validación como métrica objetivo.
#
# Al desarrollar este proceso, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Qué métrica decidieron optimizar y por qué?
#
# - ¿Qué hiperparámetro tuvo un mayor impacto en el rendimiento de su modelo?
#
# - ¿Cuánto mejoró el rendimiento del modelo después de la optimización de hiperparámetros?

# %% [markdown]
# Por lo antes dicho, se decidió optimizar sobre PR AUC pues se enfoca en la clase positiva la que para este problema es mucho más importante, es robusta a desbalance que se genera al hacer un buen negative sampling (lo que la puso sobre la ROC AUC) y aparte de esto calcula sobre todos los umbrales siendo robusta.

# %%
import optuna
from sklearn.pipeline import Pipeline
from sklearn.base import clone
from sklearn.metrics import average_precision_score
from lightgbm import LGBMClassifier

def build_lgbm_pipe(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 1200),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 31, 255),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 5.0),
        'random_state': RANDOM_STATE,
        'n_jobs': -1,
        'scale_pos_weight': scale_pos_weight,
    }
    clf = LGBMClassifier(**params)
    pipe = Pipeline(steps=[
        ('prep', clone(prep_pipeline)),
        ('clf', clf),
    ])
    return pipe

X_tr, y_tr = X_train, y_train
X_va, y_va = X_val, y_val


def objective(trial):
    pipe = build_lgbm_pipe(trial)
    pipe.fit(X_tr, y_tr)
    y_score = pipe.predict_proba(X_va)[:, 1]
    pr_auc = average_precision_score(y_va, y_score)
    trial.report(pr_auc, step=0)
    return pr_auc

sampler = optuna.samplers.TPESampler(seed=RANDOM_STATE)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=100)

print("Mejor PR AUC (validación):", study.best_value)
print("Mejores hiperparámetros:", study.best_params)
# Out:
# [I 2025-09-11 22:11:05,088] A new study created in memory with name: no-name-34c4a7e6-a6f4-4ffc-aa46-a6d63ab27a92
# [LightGBM] [Info] Number of positive: 146156, number of negative: 292312
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012912 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 438468, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333333 -> initscore=-0.693147
# [LightGBM] [Info] Start training from score -0.693147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Entrenemos entonces el modelo con los mejores parámetros para conseguir todas las métricas

# %%
best_params = study.best_params

# Crear pipeline con mejores hiperparámetros - solo usar parámetros que existen en best_params
best_lgb = LGBMClassifier(
    objective='binary',
    random_state=RANDOM_STATE,
    n_jobs=-1,
    scale_pos_weight=scale_pos_weight,
    n_estimators=best_params['n_estimators'],
    learning_rate=best_params['learning_rate'],
    num_leaves=best_params['num_leaves'],
    subsample=best_params['subsample'],
    colsample_bytree=best_params['colsample_bytree'],
    reg_lambda=best_params['reg_lambda']
)

optuna_pipe = Pipeline(steps=[
    ('prep', clone(prep_pipeline)),
    ('clf', best_lgb)
])

# Entrenamiento y predicción
eval_model("LGBMClassifier Optimizado", optuna_pipe, X_train, y_train, X_val, y_val)
# Out:
# [LightGBM] [Info] Number of positive: 146156, number of negative: 292312
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010455 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 438468, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333333 -> initscore=-0.693147
# [LightGBM] [Info] Start training from score -0.693147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Con la optimización de parámetros mejora muy ligera del orden de 0.002 en PR AUC pero debido a la velocidad del modelo, tiene sentido obtener estos parámetros

# %% [markdown]
# ## 📌 Interpretabilidad [1.0 puntos]
#
# En esta sección, deben explicar el funcionamiento de su modelo utilizando las técnicas de interpretabilidad vistas en clase, como `SHAP`. Se espera que sean capaces de descomponer las predicciones y evaluar la importancia de los atributos y las interacciones entre ellos, con el fin de obtener una comprensión más profunda de cómo el modelo toma decisiones.
#
# Al desarrollar esta parte, deberán responder las siguientes preguntas clave como mínimo:
#
# - ¿Podría explicar el funcionamiento de su modelo para una predicción en particular? Si es así, proporcione al menos tres ejemplos específicos, describiendo cómo el modelo llegó a sus decisiones y qué factores fueron más relevantes en cada caso.
#
# - ¿Qué atributo tiene una mayor importancia en la salida de su modelo? Analice si esto tiene sentido con el problema planteado y justifique la relevancia de dicho atributo en el contexto de las predicciones que se realizan.
#
# - ¿Existe alguna interacción entre atributos que sea relevante para el modelo? Investigue si la combinación de ciertos atributos tiene un impacto significativo en las predicciones y explíquela en **detalle**.
#
# - ¿Podría existir sesgo hacia algún atributo en particular? Reflexione sobre la posibilidad de que el modelo esté favoreciendo ciertos atributos. Si es así, ¿cuál podría ser la causa y qué impacto podría tener esto en la predicción?

# %%
import shap

# Usaremos el mejor pipeline con LGBM optimizado
best_pipe = optuna_pipe

# Extraer el modelo y el preprocesador del pipeline
preprocessor = best_pipe.named_steps['prep']
model = best_pipe.named_steps['clf']

# Transformar los datos de validación para obtener los nombres de las características
# Usamos una muestra para que SHAP no tarde tanto
X_val_sample = X_val.sample(10000, random_state=RANDOM_STATE)
y_val_sample = y_val.loc[X_val_sample.index]

X_val_transformed = preprocessor.transform(X_val_sample)
feature_names = preprocessor.named_steps['preprocess'].get_feature_names_out()

# Convertir a DataFrame para que SHAP muestre nombres de columnas
X_val_transformed_df = pd.DataFrame(X_val_transformed.toarray(), columns=feature_names)

# Crear el explainer de SHAP y calcular los valores
explainer = shap.TreeExplainer(model, feature_perturbation="interventional")
shap_values = explainer.shap_values(X_val_transformed_df, check_additivity=False)

# Visualización de la importancia global de las características
print("Importancia global de las características (SHAP):")
shap.summary_plot(shap_values, X_val_transformed_df, plot_type="bar", show=False)
plt.title("Importancia de Atributos (SHAP Value)")
plt.show()

print("\nDistribución de la influencia de cada característica:")
shap.summary_plot(shap_values, X_val_transformed_df, show=False)
plt.show()

# Análisis de predicciones individuales
print("\nAnálisis de predicciones individuales:")

# Obtenemos los shap_values como un objeto que contiene toda la info necesaria
shap_values_obj = explainer(X_val_transformed_df)

# Obtenemos las probabilidades para encontrar los índices de interés
y_probs = model.predict_proba(X_val_transformed_df)[:, 1]

# caso donde el modelo predijo una alta probabilidad de compra
high_prob_idx = np.argmax(model.predict_proba(X_val_transformed_df)[:, 1])
print(f"\n--- Ejemplo 1: Predicción con alta probabilidad de compra (Índice: {high_prob_idx}) ---")
# La función waterfall_plot ahora toma el objeto SHAP de la instancia que queremos explicar
shap.waterfall_plot(shap_values_obj[high_prob_idx], show=False)
plt.title(f"Explicación para la predicción del registro {high_prob_idx}")
plt.show()

# caso donde el modelo predijo una baja probabilidad de compra
low_prob_idx = np.argmin(model.predict_proba(X_val_transformed_df)[:, 1])
print(f"\n--- Ejemplo 2: Predicción con baja probabilidad de compra (Índice: {low_prob_idx}) ---")
shap.waterfall_plot(shap_values_obj[low_prob_idx], show=False)
plt.title(f"Explicación para la predicción del registro {low_prob_idx}")
plt.show()

#Un caso de predicción incierta (probabilidad cercana a 0.5)
mid_prob_idx = np.argmin(np.abs(y_probs - 0.5))
print(f"\n--- Ejemplo 3: Predicción incierta o de confianza media (Índice: {mid_prob_idx}) ---")
shap.waterfall_plot(shap_values_obj[mid_prob_idx], show=False)
plt.title(f"Explicación para la predicción del registro {mid_prob_idx}")
plt.show()

# Análisis de interacciones
print("\nAnálisis de interacciones entre características:")
shap.dependence_plot("size", shap_values, X_val_transformed_df, interaction_index="sub_category_GASEOSAS", show=False)
plt.show()

print("\n--- Interacción entre 'week_cos' y 'sub_category_GASEOSAS' ---")
shap.dependence_plot("week_cos", shap_values, X_val_transformed_df, interaction_index="sub_category_GASEOSAS", show=False)
plt.show()
# Out:
# c:\Users\potat\anaconda3\envs\cuda_env\Lib\site-packages\shap\explainers\_tree.py:253: FutureWarning: In the future, passing feature_perturbation='interventional' without providing a background dataset will raise an error. Please provide a background dataset to continue using the interventional approach or set feature_perturbation='auto' to automatically switch approaches.
#   warnings.warn(
# c:\Users\potat\anaconda3\envs\cuda_env\Lib\site-packages\shap\explainers\_tree.py:583: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(
# Importancia global de las características (SHAP):
# Distribución de la influencia de cada característica:
# Análisis de predicciones individuales:
#
# --- Ejemplo 1: Predicción con alta probabilidad de compra (Índice: 218) ---
# --- Ejemplo 2: Predicción con baja probabilidad de compra (Índice: 121) ---
# --- Ejemplo 3: Predicción incierta o de confianza media (Índice: 230) ---
# ...

# %% [markdown]
# El modelo se puede explicar para predicciones específicas utilizando los gráficos de cascada de SHAP que muestran cómo cada característica contribuye a mover la predicción desde un valor base hasta el valor final.
#
# *   **Ejemplo 1: Predicción con alta probabilidad de compra:** En el primer gráfico de cascada, vemos una predicción que es significativamente más alta que la base. Los factores que más contribuyen a **aumentar** la probabilidad de compra (flechas rojas) son un valor específico de `brand` y `size` (podría ser por la existencia de productos de ciertas marcas muy famosos por ejemplo las bebidas de la marca Cocacola Company).
#
# *   **Ejemplo 2: Predicción con baja probabilidad de compra:** En el segundo gráfico, la predicción final es mucho más baja que la base. Los factores que más disminuyen la probabilidad de compra (flechas azules) son la `sub_caterory` de AGUA SABORIZADA como 1 y de gaseosa como 0.
#
# *   **Ejemplo 3: Predicción incierta:** En el tercer gráfico, la predicción final se mantiene muy cerca del valor base. Este es un caso donde el modelo no está seguro. Vemos que muchas features tienen mucha importancia, de hecho es el único gráfica donde la suma de importancia de las features que no salen en el gráfico es mayor a cualquier feature por separado.
#
# El atributo con mayor importancia global, según el gráfico de barras de SHAP, es `size`, seguido de `sub_category_AGUAS SABORIZADAS` lo que puede indicar los productos de agua saborizada se compran mucho y que quizas por este mismo motivo, como las aguas saborizadas tienen un cierto tamaño, también afecta size pues están muy correlacionadas.
#
# Sí, los gráficos de dependencia de SHAP revelan interacciones importantes:
#
# *   **Interacción entre `size` y `sub_category_GASEOSAS`**: El gráfico de dependencia para `size` muestra que el impacto de esta variable en la predicción depende de si el producto es una gaseosa o no (representado por el color). Se puede observar que para productos de tamaño pequeño, el hecho de que no sea una gaseosa hace que el valor SHAP sea cercano a 0, es decir, para productos que no son gaseosas no importa mucho el tamaño, pero para productos que si lo son importa bastante.
#
# *   **Interacción entre `week_cos` y `sub_category_GASEOSAS`**: De manera similar, el gráfico de dependencia para `week_cos` muestra que el efecto de la estacionalidad varía según si es una gaseosa el producto o no, lo que tiene mucho sentido pues en ciertas épocas más calurosas se compra más gaseosa.
#
# Podría existir un sesgo de popularidad implícito, es decir, el modelo podría favorecer la recomendación de productos que históricamente han sido populares (ciertos `size` o `brand`) o a clientes de alto volumen (`num_deliver_per_week` alto). La causa es que el modelo aprende de los patrones existentes en los datos de transacciones. Si un producto nunca se ha vendido a un tipo de cliente, el modelo tendrá dificultades para recomendarlo. Esto podría crear un ciclo de retroalimentación donde los productos populares se vuelven aún más populares, limitando la diversidad de las recomendaciones y la capacidad de descubrir nuevas preferencias de los clientes.

# %% [markdown]
# ## 📌 Resultados y Conclusiones [1.0 puntos]
#
# Para finalizar, se deben explicar los desarrollos y resultados obtenidos a lo largo de todo el proceso, desde la selección de las variables hasta la optimización de hiperparámetros e interpretación. Se espera una reflexión crítica sobre el desempeño de los modelos entrenados y una comparación entre los diferentes enfoques. Además, deberán abordar los siguientes puntos clave:
#
# - **Análisis de métricas**: Comenten sobre las métricas obtenidas en cada etapa del modelo, destacando las más relevantes como precisión, recall, F1-score, etc. ¿Cuáles fueron los modelos más efectivos? ¿Qué diferencias notables encontró entre ellos?
#
# - **Impacto de las decisiones tomadas**: Reflexionen sobre cómo las decisiones relacionadas con el preprocesamiento, selección de atributos y optimización de hiperparámetros influyeron en los resultados finales. ¿Hubo alguna decisión que haya tenido un impacto notable en el rendimiento?
#
# - **Lecciones aprendidas**: Concluyan sobre las lecciones más importantes que aprendieron durante el proceso y cómo estas pueden influir en futuras iteraciones del modelo. ¿Qué se podría mejorar si se repitiera el proceso? Si tuvieran más recursos y tiempo, ¿qué otras técnicas/herramientas habrían utilizado?

# %% [markdown]
# A lo largo de este proyecto, se desarrolló un sistema completo para predecir la probabilidad de compra de productos, desde el preprocesamiento de datos hasta la interpretabilidad del modelo final.
#
# **Análisis de Métricas y Modelos:**
# El modelo baseline, un `DecisionTreeClassifier`, estableció un punto de referencia inicial. En la fase de selección, se compararon cuatro modelos, donde `LGBMClassifier` destacó significativamente con un **PR AUC de 0.689** y un **F1-Score de 0.6778** en el conjunto de validación, superando a `RandomForestClassifier`, `ExtraTreesClassifier` y `GradientBoostingClassifier`. Esta superioridad se atribuye a su eficiencia en el manejo de datos dispersos (generados por el One-Hot Encoding) y su algoritmo de boosting basado en gradientes con hojas, que le permite capturar patrones complejos de manera más rápida. Tras la optimización con Optuna, el `LGBMClassifier` mejoró su **PR AUC a 0.691**, demostrando que en este caso no fue tan esencial la optimización de hiperparámetros y depende su importancia fuertemente del tamaño del modelo.
#
# **Impacto de las Decisiones Tomadas:**
# La decisión más influyente fue la reestructuración del problema en un formato semanal (cliente-producto-semana) con **muestreo de negativos**. Esto transformó un problema de series de tiempo implícito en un formato de clasificación manejable y redujo el desbalance de clases, permitiendo que los modelos aprendieran patrones.
#
# **Lecciones Aprendidas y Pasos Futuros:**
# La principal lección es la importancia de un correcto planteamiento del problema y un feature engineering alineado al negocio, ya que, una enorme parte del rendimiento que tiene el modelo viene de un buen preprocesamiento y EDA.
#
# Para futuras iteraciones, se podrían explorar las siguientes mejoras:
# 1.  **Feature Engineering Avanzado**: Incorporar características basadas en el historial del cliente (ej. "días desde la última compra de este producto", "gasto promedio semanal") y en la popularidad del producto (ej. "unidades vendidas la semana anterior").
# 2.  **Modelos más Complejos**: Experimentar con arquitecturas de redes neuronales o modelos híbridos que puedan capturar mejor las interacciones temporales.
# 3.  **Optimización del Pipeline**: Integrar la selección de la ratio de muestreo de negativos como un hiperparámetro a optimizar dentro de Optuna, para encontrar el balance ideal.
# 4. **Embeddings de usuarios y productos**: Para aprovechar la relación que existe entre los productos se podrian agregar embeddings como input al modelo para capturar estas relaciones ya que como OHE cada cosa es tan igual de distinta que la otra siendo que en la práctica se pueden utilizar relaciones entre entidades.

# %% [markdown]
# Mucho éxito!
#
# <center>
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExaHpvOTY5Z3hpdHI3aDBpdGRueXRqamZncXp2emFrbjJ5M2s5eTR1dSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1PMVNNKVIL8Ig/giphy.gif" width="300" height="200">
